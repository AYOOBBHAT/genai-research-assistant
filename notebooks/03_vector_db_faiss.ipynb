# %% [markdown]
# <a href="https://colab.research.google.com/github/AYOOBBHAT/genai-research-assistant/blob/main/03_vector_db_faiss.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q faiss-cpu
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.8/23.8 MB 62.8 MB/s eta 0:00:00

# %%
import faiss
import numpy as np

# %%
dimension = doc_embeddings.shape[1]
index = faiss.IndexFlatL2(dimension)
index.add(doc_embeddings)

# %%
k = 2
D, I = index.search(np.array([query_embedding]), k)

for idx in I[0]:
    print(documents[idx])
