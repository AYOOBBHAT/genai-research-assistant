# %% [markdown]
# <a href="https://colab.research.google.com/github/AYOOBBHAT/genai-research-assistant/blob/main/02_embeddings_similarity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q sentence-transformers

# %%
from sentence_transformers import SentenceTransformer
import numpy as np

# %% [markdown]
# load embedding model

# %%
model=SentenceTransformer('all-MiniLM-L6-v2')

# %%
documents=[
     "AI improves healthcare",
    "Machine learning helps doctors",
    "Football is a popular sport",
    "Deep learning models use neural networks"
]
doc_embeddings=model.encode(documents)

# %% [markdown]
# define similarity search

# %%
def cosine_sim(a,b):
  return np.dot(a,b)/(np.linalg.norm(a)*np.linalg.norm(b))

query="Ai is a machine"
query_embeddings=model.encode(query)
scores=[cosine_sim(query_embeddings,emb) for emb in doc_embeddings]
for doc,score in zip(documents,scores):
  print(f"{score:.3f}->{doc}")
